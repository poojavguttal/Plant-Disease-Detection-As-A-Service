# %% [markdown]
# # PlantVillage Preprocessing Report

# %% [markdown]
# This notebook was auto-generated after running the preprocessing pipeline. It documents dataset structure, class counts, sample images, and the train/val/test split.

# %% [markdown]
# **Data root:** `/app/data/processed`
# **Image size:** 224×224
# **Splits:** train / val / test

# %%
import os, json, random
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image
DATA_ROOT = Path('/app/data/processed')
# %matplotlib inline

# %% [markdown]
# ## Class Counts (Train / Val / Test)

# %%
import pandas as pd
train_counts = {
  "Pepper__bell___Bacterial_spot": 0,
  "Pepper__bell___healthy": 0,
  "Potato___Early_blight": 0,
  "Potato___Late_blight": 0,
  "Potato___healthy": 0,
  "Tomato_Bacterial_spot": 0,
  "Tomato_Early_blight": 0,
  "Tomato_Late_blight": 102,
  "Tomato_Leaf_Mold": 0,
  "Tomato_Septoria_leaf_spot": 0,
  "Tomato_Spider_mites_Two_spotted_spider_mite": 0,
  "Tomato__Target_Spot": 0,
  "Tomato__Tomato_YellowLeaf__Curl_Virus": 0,
  "Tomato__Tomato_mosaic_virus": 0,
  "Tomato_healthy": 0
}
val_counts   = {
  "Pepper__bell___Bacterial_spot": 0,
  "Pepper__bell___healthy": 1,
  "Potato___Early_blight": 0,
  "Potato___Late_blight": 0,
  "Potato___healthy": 0,
  "Tomato_Bacterial_spot": 0,
  "Tomato_Early_blight": 0,
  "Tomato_Late_blight": 28,
  "Tomato_Leaf_Mold": 0,
  "Tomato_Septoria_leaf_spot": 0,
  "Tomato_Spider_mites_Two_spotted_spider_mite": 0,
  "Tomato__Target_Spot": 0,
  "Tomato__Tomato_YellowLeaf__Curl_Virus": 0,
  "Tomato__Tomato_mosaic_virus": 0,
  "Tomato_healthy": 1
}
test_counts  = {
  "Pepper__bell___Bacterial_spot": 0,
  "Pepper__bell___healthy": 1,
  "Potato___Early_blight": 0,
  "Potato___Late_blight": 0,
  "Potato___healthy": 0,
  "Tomato_Bacterial_spot": 0,
  "Tomato_Early_blight": 0,
  "Tomato_Late_blight": 23,
  "Tomato_Leaf_Mold": 0,
  "Tomato_Septoria_leaf_spot": 0,
  "Tomato_Spider_mites_Two_spotted_spider_mite": 0,
  "Tomato__Target_Spot": 0,
  "Tomato__Tomato_YellowLeaf__Curl_Virus": 0,
  "Tomato__Tomato_mosaic_virus": 0,
  "Tomato_healthy": 0
}
df = pd.DataFrame({'train': train_counts, 'val': val_counts, 'test': test_counts}).fillna(0).astype(int)
df
# Out:
#                                              train  val  test
# Pepper__bell___Bacterial_spot                    0    0     0
# Pepper__bell___healthy                           0    1     1
# Potato___Early_blight                            0    0     0
# Potato___Late_blight                             0    0     0
# Potato___healthy                                 0    0     0
# Tomato_Bacterial_spot                            0    0     0
# Tomato_Early_blight                              0    0     0
# Tomato_Late_blight                             102   28    23
# Tomato_Leaf_Mold                                 0    0     0
# Tomato_Septoria_leaf_spot                        0    0     0
# Tomato_Spider_mites_Two_spotted_spider_mite      0    0     0
# Tomato__Target_Spot                              0    0     0
# Tomato__Tomato_YellowLeaf__Curl_Virus            0    0     0
# Tomato__Tomato_mosaic_virus                      0    0     0
# ...

# %% [markdown]
# ### Bar Chart (Train/Val/Test by Class)

# %%
ax = df.plot(kind='bar', figsize=(10,5))
ax.set_xlabel('Class')
ax.set_ylabel('Image count')
ax.set_title('Per-class image counts by split')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sample Images (Train)

# %%
from PIL import Image
import matplotlib.pyplot as plt
samples = [
  "/app/data/processed/train/Tomato_Late_blight/5d8d97e7-8a2f-459f-a610-c26af46c7f5f___GHLB_PS Leaf 25.2 Day 16.jpg",
  "/app/data/processed/train/Tomato_Late_blight/1159051e-1278-4b35-929c-e26b963d048f___GHLB_PS Leaf 8.1 Day 16.jpg",
  "/app/data/processed/train/Tomato_Late_blight/cac3a565-799f-4b66-a575-5ad6ff356d37___GHLB_PS Leaf 2.3 Day 8.jpg",
  "/app/data/processed/train/Tomato_Late_blight/d0badc95-d04c-457b-8db8-aa6e198f4bd6___GHLB Leaf 10 Day 6.jpeg",
  "/app/data/processed/train/Tomato_Late_blight/bb1cfbc3-b8eb-4a56-9313-86cffbea4524___GHLB_PS Leaf 30.1 Day 13.jpg",
  "/app/data/processed/train/Tomato_Late_blight/baaa63dc-483f-44a6-ae09-855923e1607e___GHLB_PS Leaf 23.2 Day 9.jpg"
]
for p in samples:
    try:
        img = Image.open(p).convert('RGB')
        plt.figure(figsize=(3,3))
        plt.imshow(img)
        plt.title(Path(p).parent.name)
        plt.axis('off')
        plt.show()
    except Exception as e:
        print('Could not open', p, e)

# %% [markdown]
# ## Split Summary

# %%
tot_train = sum(train_counts.values()) if len(train_counts:=train_counts) else 0
tot_val   = sum(val_counts.values())   if len(val_counts:=val_counts) else 0
tot_test  = sum(test_counts.values())  if len(test_counts:=test_counts) else 0
summary = pd.DataFrame({'split':['train','val','test'], 'count':[tot_train, tot_val, tot_test]})
summary
# Out:
#    split  count
# 0  train    102
# 1    val     30
# 2   test     24

# %%
ax = summary.set_index('split').plot(kind='bar', figsize=(5,3), legend=False)
ax.set_ylabel('Images')
ax.set_title('Total images by split')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Notes

# %% [markdown]
# - Images resized to **224×224** during preprocessing.
# - Normalization will be applied at **training time** (dataloader).
# - Classes shown reflect filtered crops (Tomato, Potato, Corn).
# - This notebook is **auto-generated**; re-run preprocessing to refresh.
